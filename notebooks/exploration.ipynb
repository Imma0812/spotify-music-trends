# %% [markdown]
# # Spotify Music Trends - exploration
#
# Notebook d'analyse exploratoire sur le dataset Spotify (Kaggle).
# Objectif : comprendre les caracteristiques audio par genre, identifier des correlations et nourrir le dashboard.

# %%
import sys
from pathlib import Path

# permet d importer src/ depuis le notebook
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import plotly.express as px

from src.data_loader import load_dataset
from src.transform import clean, features_by_genre
from src.analysis import top_genres, correlation_matrix, compare_genres

# %%
df = clean(load_dataset())
df.shape, df.columns.tolist()

# %% [markdown]
# ## Apercu du dataset

# %%
df.head()

# %%
df.describe(include='all').T.head(20)

# %% [markdown]
# ## Top genres par popularite

# %%
top = top_genres(df, n=15)
px.bar(top, x='popularite_moyenne', y='track_genre', orientation='h')

# %% [markdown]
# ## Correlations entre features audio

# %%
corr = correlation_matrix(df)
px.imshow(corr, text_auto='.2f', color_continuous_scale='RdBu_r', zmin=-1, zmax=1)

# %% [markdown]
# ## Comparaison de genres

# %%
compare_genres(df, ['pop', 'jazz', 'metal']).round(3)

# %% [markdown]
# ## Statistiques par genre
#
# Pour identifier les genres les plus dansants, les plus energiques, etc.

# %%
by_genre = features_by_genre(df)
by_genre.sort_values('danceability', ascending=False).head(10)[['track_genre', 'danceability', 'energy', 'valence', 'popularity']]
